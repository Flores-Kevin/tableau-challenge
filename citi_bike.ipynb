# %%
import pandas as pd

# %%
path = "../../202208-citibike-tripdata.csv"

# %%
path_2 = "../../JC-202208-citibike-tripdata.csv"

# %%
df1 = pd.read_csv(path)
# Out:
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2 = pd.read_csv(path_2)

# %%
df1.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  428051654CF1145B   classic_bike  2022-08-28 00:34:58  2022-08-28 00:55:20
# 1  7282036E3ECDDD65   classic_bike  2022-08-31 16:33:38  2022-08-31 16:35:17
# 2  375C59BE1271E31C  electric_bike  2022-08-27 23:22:10  2022-08-27 23:34:57
# 3  7281A7F21CE571AF   classic_bike  2022-08-26 19:01:01  2022-08-26 19:09:26
# 4  A5093D7D77713F87   classic_bike  2022-08-25 22:16:16  2022-08-25 22:29:13
#
#         start_station_name start_station_id         end_station_name  \
# 0    Walker St & Baxter St          5351.07  Lexington Ave & E 24 St
# 1  Lexington Ave & E 29 St          6164.09  Lexington Ave & E 24 St
# 2   E 132 St & Madison Ave          7748.02   Melrose Ave & E 150 St
# 3  Lexington Ave & E 29 St          6164.09          E 13 St & 2 Ave
# 4      E 16 St & Irving Pl          5938.11          W 31 St & 7 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
df2.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  D68047AAA9A72501   classic_bike  2022-08-12 18:14:45  2022-08-12 18:21:23
# 1  E5B82A9F588A7650   classic_bike  2022-08-19 01:04:39  2022-08-19 01:14:10
# 2  13D19CCBCC9D7B76   classic_bike  2022-08-19 18:13:45  2022-08-19 19:32:47
# 3  AA0DBFF220DA98F6   classic_bike  2022-08-21 13:43:05  2022-08-21 13:53:13
# 4  8F11D340492FCD32  electric_bike  2022-08-04 22:02:12  2022-08-04 22:21:31
#
#                              start_station_name start_station_id  \
# 0                                Columbus Drive            JC014
# 1  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
# 2  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
# 3                                Columbus Drive            JC014
# 4  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
#
#         end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
df1.count()
# Out:
# ride_id               3681309
# rideable_type         3681309
# started_at            3681309
# ended_at              3681309
# start_station_name    3681309
# start_station_id      3681309
# end_station_name      3670904
# end_station_id        3670904
# start_lat             3681309
# start_lng             3681309
# end_lat               3676781
# end_lng               3676781
# member_casual         3681309
# dtype: int64

# %%
df2.count()
# Out:
# ride_id               115231
# rideable_type         115231
# started_at            115231
# ended_at              115231
# start_station_name    115231
# start_station_id      115231
# end_station_name      114840
# end_station_id        114840
# start_lat             115231
# start_lng             115231
# end_lat               115011
# end_lng               115011
# member_casual         115231
# dtype: int64

# %%
link3 = "../../JC-201811-citibike-tripdata.csv"
link4 = "../../JC-201804-citibike-tripdata.csv"

# %%
df3 = pd.read_csv(link3)
df4 = pd.read_csv(link4)

# %%
df3.index += 23634

# %%
df3
# Out:
#        tripduration                 starttime                  stoptime  \
# 23634          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 23635           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 23636           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 23637           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 23638            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
# ...             ...                       ...                       ...
# 48539           734  2018-11-28 10:46:12.6640  2018-11-28 10:58:27.0750
# 48540           312  2018-11-28 19:52:40.1140  2018-11-28 19:57:52.9270
# 48541           914  2018-11-29 10:20:57.7240  2018-11-29 10:36:12.0420
# 48542          2392  2018-11-29 17:28:24.1590  2018-11-29 18:08:16.8720
# 48543           637  2018-11-30 12:00:10.4100  2018-11-30 12:10:48.0210
#
#        start station id start station name  start station latitude  \
# ...

# %%
df4
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1               298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2              1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3              1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4               559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
# ...             ...                       ...                       ...
# 23629           350  2018-04-30 12:34:25.4670  2018-04-30 12:40:16.0780
# 23630           571  2018-04-30 15:15:33.5140  2018-04-30 15:25:05.0550
# 23631           195  2018-04-30 18:29:09.0680  2018-04-30 18:32:24.1090
# 23632           106  2018-04-30 18:53:02.3630  2018-04-30 18:54:48.4980
# 23633           746  2018-04-30 19:02:56.9550  2018-04-30 19:15:23.3070
#
#        start station id start station name  start station latitude  \
# ...

# %%
# merged_df = pd.merge(df4,df3,on=None)
# df4.merge(df3,left_index=True,)
df3 = df3.reset_index()

# %%
# merged_df = df4.join(df3)
df4 = df4.reset_index()

# %%
# merged_df = pd.merge(df4,df3,on='index')
merged_df = df4.append(df3)

# %%
merged_df
# Out:
#        index  tripduration                 starttime  \
# 0          0          1814  2018-04-01 09:43:51.1590
# 1          1           298  2018-04-01 11:42:53.7090
# 2          2          1060  2018-04-01 12:43:11.9640
# 3          3          1035  2018-04-01 12:43:40.5890
# 4          4           559  2018-04-01 12:56:47.4600
# ...      ...           ...                       ...
# 24905  48539           734  2018-11-28 10:46:12.6640
# 24906  48540           312  2018-11-28 19:52:40.1140
# 24907  48541           914  2018-11-29 10:20:57.7240
# 24908  48542          2392  2018-11-29 17:28:24.1590
# 24909  48543           637  2018-11-30 12:00:10.4100
#
#                        stoptime  start station id start station name  \
# 0      2018-04-01 10:14:06.1300              3183     Exchange Place
# 1      2018-04-01 11:47:51.8770              3183     Exchange Place
# 2      2018-04-01 13:00:52.8700              3183     Exchange Place
# ...

# %%
merged_df.to_csv('merged.csv', index=False)
